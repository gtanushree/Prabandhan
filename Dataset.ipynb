# %%
import pandas as pd
import numpy as np
import random
from datetime import datetime, timedelta

# %%
departments = ['Agriculture Department', 'Backward Class Welfare Department', 'Basic Education Department', 'Culture Department', 'Dairy Development Department', 'State Election Department', 'Empowerment of Persons With Disabilities Department', 'Energy Department (UPNEDA)', 'Excise Department', 'Finance Department', 'Fisheries Department', 'Food and Civil Supplies Department', 'Food Safety and Drug Administration Department', 'Environment, Forest and Climate Change Department', 'Handloom and Textile Industry Department', 'Higher Education Department', 'Home Department', 'Horticulture and Food Processing Department', 'Housing and Urban Planning Department', 'Khadi and Village Industries (Khadi Udyog) Department', 'Labour Department', 'Irrigation & Water Resources Department Uttar Pradesh', 'Medical Health and Family Welfare Department', 'Minor Irrigation Department', 'MSME and Export Promotion Department', 'Panchayati Raj Department', 'Planning Department', 'Public Works Department (PWD)', 'Rural Engineering Department', 'Secondary Education Department', 'Department of Social Welfare', 'Sports Department', 'Stamps and Registartion Department', 'Tourism Department', 'Urban Development Department', 'Vocational Education and Skill Development Department', 'Woman Welfare Department', 'Uttar Pradesh Sainik Rehabilitation Fund', 'Jal Kal Vibhag Agra', 'Local Bodies']

statuses = ["Completed", "Ongoing", "Upcoming"]

project_types = {
    'Agriculture Department' : ['Crop insurance', 'soil testing labs', 'farmer support schemes', 'irrigation enhancements', 'agro-tech adoption'],
    'Backward Class Welfare Department' : ['Hostel construction', 'scholarship disbursement systems', 'awareness drives', 'community development'],
    'Basic Education Department' : ['Primary school upgrades', 'mid-day meal management', 'digital classrooms', 'teacher training'],
    'Culture Department' : ['Cultural center renovations', 'event promotion systems', 'digitization of heritage content'],
    'Dairy Development Department' : ['Milk collection center setup', 'cold chain infrastructure', 'dairy farmer training'],
    'State Election Department' : ['EVM tracking', 'voter list digitization', 'training centers for polling staff'],
    'Empowerment of Persons With Disabilities' : ['Accessible infrastructure', 'skill training centers', 'prosthetic distribution systems'],
    'Energy Department (UPNEDA)' : ['Solar panel installations', 'streetlight electrification', 'smart metering projects'],
    'Excise Department' : ['Online liquor licensing', 'inventory control systems', 'anti-smuggling intelligence'],
    'Finance Department' : ['Budget tracking tools', 'e-governance for treasury', 'financial dashboards'],
    'Fisheries Department' : ['Fish hatchery setup', 'pond renovation', 'aqua-tech infrastructure'],
    'Food and Civil Supplies Department' : ['Ration card digitization', 'warehouse modernization', 'FPS automation'],
    'Food Safety and Drug Administration' : ['Food testing labs', 'inspection tracking', 'drug license management'],
    'Environment, Forest and Climate Change' : ['Plantation drives', 'wildlife monitoring systems', 'pollution sensors deployment'],
    'Handloom and Textile Industry' : ['Weavers cluster development', 'loom tech upgrade', 'exhibition facilitation'],
    'Higher Education Department' : ['University automation', 'research funding portals', 'college accreditation systems'],
    'Home Department' : ['Police modernization', 'forensic lab upgrade', 'emergency response systems'],
    'Horticulture and Food Processing' : ['Fruit processing units', 'cold storage networks', 'farmer market linkage systems'],
    'Housing and Urban Planning' : ['Affordable housing schemes', 'smart housing dashboards', 'GIS-based land mapping'],
    'Khadi and Village Industries' : ['Marketing platforms', 'artisan training centers', 'rural entrepreneurship incubation'],
    'Labour Department' : ['Migrant worker portals', 'skill registry', 'e-Labour card implementation'],
    'Irrigation & Water Resources' : ['Canal lining', 'check dams', 'remote sensing for water level monitoring'],
    'Medical Health and Family Welfare' : ['PHC construction', 'immunization tracking', 'hospital data systems'],
    'Minor Irrigation Department' : ['Tube wells', 'micro-irrigation tech', 'small check dams'],
    'MSME & Export Promotion' : ['Export promotion clusters', 'e-marketing platforms', 'common facility centers'],
    'Panchayati Raj Department' : ['Gram Panchayat MIS', 'rural infra monitoring', 'sanitation projects'],
    'Planning Department' :	['Project monitoring dashboards', 'data observatories', 'multi-sector integration'],
    'Public Works Department (PWD)' : ['Road and bridge construction', 'maintenance scheduling', 'building audits'],
    'Rural Engineering Department' : ['Village road laying', 'drainage projects', 'rural building constructions'],
    'Secondary Education Department' : ['Smart classroom implementation', 'textbook digitization', 'school infrastructure expansion'],
    'Department of Social Welfare' : ['Pension disbursement systems', 'caste certificate automation', 'community halls'],
    'Sports Department' : ['Stadium upgrades', 'sports training academies', 'athlete scholarships'],
    'Stamps and Registration Department' : ['E-registry systems', 'property records digitization', 'online deed verification'],
    'Tourism Department' : ['Tourist site beautification', 'wayfinding systems', 'mobile tourism apps'],
    'Urban Development Department' : ['Waste management systems', 'water supply projects', 'urban mobility tracking'],
    'Vocational Education and Skill Development' : ['Skill center setup', 'industry-aligned training modules', 'placement tracking'],
    'Woman Welfare Department' : ['Women’s shelter homes', 'financial literacy programs', 'health camps'],
    'U.P. Sainik Rehabilitation Fund' :	['Veteran welfare schemes', 'housing projects', 'education funds for children'],
    'Jal Kal Vibhag Agra' :	['Urban water pipeline projects', 'sewage treatment', 'water quality monitoring'],
    'Local Bodies' : ['Municipal waste collection', 'streetlight maintenance', 'grievance redressal apps']
}

project_name = {
    'Agriculture Department' : ["Krishi Lab Yojana", "Smart Soil Grid Agra", "PM-KISAN Support Outreach", "Agri Credit Direct Benefit Portal", "Drone-based Crop Mapping", "AI Pest Detection Pilot"],
    'Backward Class Welfare Department' : [ "OBC Merit Support 2025", "Hostel Admission Scholarship Portal", "Backward Class Residential Colony Scheme"],
    'Basic Education Department' : ["Smart Shiksha School Upliftment", "Boundary Wall Revamp Drive", "Digital Mid-Day Meal Monitoring"],
    'Culture Department' : [ "Digitization of Fort Archives", "Heritage Awareness Caravan", "UP Cultural Festival Planner", "Mobile Art Bus Project"],
    'Dairy Development Department' : ["Milk Cold Chain Agra", "Automatic Milking System Setup"],
    'State Election Department' : ["e-Voting Booth Dashboard", "Voter Awareness Rallies Monitoring"],
    'Empowerment of Persons With Disabilities' : [ "Ramp Up Scheme", "Accessible School Infrastructure Tracker", "Artificial Limb Distribution Tracking"],
    'Energy Department (UPNEDA)' : ["Agra Solar Rooftop Phase II", "LED Village Electrification"],
    'Excise Department' : ["Liquor Inventory Management Portal", "Online Permit Generator"],
    'Finance Department' : ["KoshVani Realtime Dashboard", "Treasury AI Audit Tool"],
    'Fisheries Department' : ["Pond Modernization Scheme", "Fish Feed Storage Units"],
    'Food and Civil Supplies Department' : ["eRation Card Sync Drive", "FPS Smart Machine Deployment"],
    'Food Safety and Drug Administration' : ["Digital Lab Audit Tracker", "Pharmacy Compliance Alerts"],
    'Environment, Forest and Climate Change' : ["Harit Kranti Plantation Phase III", "Wildlife Corridor AI Monitoring"],
    'Handloom and Textile Industry' : ["Varanasi Loom Tech Upgradation", "Weaver e-Marketplace Launch"],
    'Higher Education Department' : ["College WiFi Coverage 100%", "Exam Automation System Rollout"],
    'Home Department' : ["eFIR Integration Hub", "Safe City Surveillance Grid"],
    'Horticulture and Food Processing' : ["Fruit Canning Unit Pilot", "Agri Export Cold Chain Link"],
    'Housing and Urban Planning' : ["PM Awas Geo-Map Interface", "Affordable Housing GIS Layers"],
    'Khadi and Village Industries' : ["Khadi Fashion Portal", "Gramudyog Mobile Cart Push"],
    'Labour Department' : ["eShram Card Integration Dashboard", "Migrant Worker Relief Monitoring"],
    'Irrigation & Water Resources' : ["Canal Realignment Scheme", "Check Dam Geo-Monitoring"],
    'Medical Health and Family Welfare' : ["PHC Expansion Tracker", "eVaccination App Phase II"],
    'Minor Irrigation Department' : ["Mini Dam Development Scheme", "Tube Well Inspection Tracker"],
    'MSME & Export Promotion' : ["MSME International Expo Dashboard", "One District One Product Tracker"],
    'Panchayati Raj Department' : ["Digital Gram Sabha Log", "Panchayat Asset Geo-Mapping"],
    'Planning Department' :	["Unified Department Monitoring System", "Project Forecast AI Tool"],
    'Public Works Department (PWD)' : ["Agra-Inner Ring Road Monitoring", "Bridge Condition Digital Audit"],
    'Rural Engineering Department' : ["Grameen Nali Yojana", "Interlock Pathway Infra Portal"],
    'Secondary Education Department' : ["Smart Class Setup Phase II", "e-Content Streaming Trial"],
    'Department of Social Welfare' : ["Vridha Pension e-KYC Project", "Caste Certificate Auto-Issuance"],
    'Sports Department' : ["Stadium Renovation Scheme", "Rural Sports Talent Hunt Tracker"],
    'Stamps and Registration Department' : ["e-Deed Integration System", "Online Mutation Portal Expansion"],
    'Tourism Department' : ["Taj Corridor Beautification", "UP Darshan App Enhancement"],
    'Urban Development Department' : ["Smart Waste Bin Network", "City Bus Route Optimization Pilot"],
    'Vocational Education and Skill Development' : ["Mega Skill Center Setup", "Job Fair Data Tracking Portal"],
    'Woman Welfare Department' : ["Nari Suraksha Hotspot Alert System", "Skill4Her Tracker"],
    'U.P. Sainik Rehabilitation Fund' :	["Veteran Medical Aid Disbursement", "Sainik Housing Welfare Portal"],
    'Jal Kal Vibhag Agra' :	["Agra Water Pressure Map", "STP Upgrade Phase I"],
    'Local Bodies' : ["Street Light eComplaint Platform", "Property Tax Dashboard"]
}

project_definitions = {
    "Agriculture Department": ("Soil Testing & Fertility", "Last Decade"),
    "Backward Class Welfare Department": ("Hostel & Scholarship", "Last to Last Decade"),
    "Basic Education Department": ("School Infrastructure", "Last Decade"),
    "Culture Department": ("Heritage Digitization", "Last Decade"),
    "Dairy Development Department": ("Cold Chain Infrastructure", "Last to Last Decade"),
    "State Election Department": ("EVM Management", "Last Decade"),
    "Empowerment of Persons With Disabilities Department": ("Accessible Infra", "Last Decade"),
    "Energy Department": ("Solar Rooftops", "Last Decade"),
    "Excise Department": ("Online Licensing", "Last Decade"),
    "Finance Department": ("Budget Dashboard", "Last Decade"),
    "Fisheries Department": ("Pond Renovation", "Last to Last Decade"),
    "Food and Civil Supplies Department": ("Ration Card Digitization", "Last Decade"),
    "Food Safety and Drug Administration Department": ("Food Lab Setup", "Last Decade"),
    "Environment, Forest and Climate Change Department": ("Plantation Drive", "Last Decade"),
    "Handloom and Textile Industry Department": ("Loom Upgrade", "Last to Last Decade"),
    "Higher Education Department": ("Digital University", "Last Decade"),
    "Home Department": ("Police Digitization", "Last Decade"),
    "Horticulture and Food Processing Department": ("Cold Storage", "Last Decade"),
    "Housing and Urban Planning Department": ("Affordable Housing", "Last Decade"),
    "Khadi and Village Industries Department": ("e-Marketing Platform", "Last Decade"),
    "Labour Department": ("eShram Registry", "Last Decade"),
    "Irrigation & Water Resources Department": ("Canal Lining", "Last to Last Decade"),
    "Medical Health and Family Welfare Department": ("PHC Expansion", "Last Decade"),
    "Minor Irrigation Department": ("Tube Wells", "Last to Last Decade"),
    "MSME and Export Promotion Department": ("Export Cluster", "Last Decade"),
    "Panchayati Raj Department": ("Village MIS", "Last Decade"),
    "Planning Department": ("Data Dashboard", "Last Decade"),
    "Public Works Department": ("Road Construction", "Last to Last Decade"),
    "Rural Engineering Department": ("Drainage Projects", "Last Decade"),
    "Secondary Education Department": ("Smart Classrooms", "Last Decade"),
    "Department of Social Welfare": ("Pension Portal", "Last Decade"),
    "Sports Department": ("Stadium Upgrade", "Last Decade"),
    "Stamps and Registration Department": ("Online Deeds", "Last Decade"),
    "Tourism Department": ("Site Beautification", "Last Decade"),
    "Urban Development Department": ("Waste Mgmt System", "Last Decade"),
    "Vocational Education and Skill Development Department": ("Skill Center", "Last Decade"),
    "Woman Welfare Department": ("Protection Services", "Last Decade"),
    "Uttar Pradesh Sainik Rehabilitation Fund": ("Veteran Housing", "Last to Last Decade"),
    "Jal Kal Vibhag Agra": ("Water Pipeline", "Ongoing"),
    "Local Bodies": ("Street Light Management", "Ongoing")
}

collaboration_map = {
    ("Public Works Department", "Road Construction"): ["Urban Development Department", "Local Bodies", "Jal Kal Vibhag Agra"],
    ("Secondary Education Department", "Smart Classrooms"): ["Basic Education Department", "Planning Department"],
    ("Medical Health and Family Welfare Department", "PHC Expansion"): ["Rural Engineering Department", "Energy Department", "Jal Kal Vibhag Agra"],
    ("Jal Kal Vibhag Agra", "Water Pipeline"): ["Urban Development Department", "Local Bodies", "Environment, Forest and Climate Change Department"],
    ("Housing and Urban Planning Department", "Affordable Housing"): ["Urban Development Department", "Public Works Department", "Energy Department"],
    ("Urban Development Department", "Waste Management System"): ["Local Bodies", "Environment, Forest and Climate Change Department", "Energy Department"],
    ("Labour Department", "eShram Registry"): ["Planning Department", "Department of Social Welfare"],
    ("Panchayati Raj Department", "Village MIS"): ["Planning Department", "Rural Engineering Department"],
    ("Energy Department", "Solar Rooftops"): ["Housing and Urban Planning Department", "Urban Development Department", "Higher Education Department"],
    ("Vocational Education and Skill Development Department", "Skill Center"): ["MSME and Export Promotion Department", "Planning Department", "Department of Social Welfare"]
}

agra_locations = [
    "Tajganj", "Sikandra", "Dayal Bagh", "Kamla Nagar", "Civil Lines",
    "Khandari", "Fatehabad Road", "Shahganj", "Rajpur Chungi", "Lohamandi",
    "Chhipitola", "Trans Yamuna Colony", "Vibhav Nagar", "Rakabganj",
    "Belanganj", "Foundry Nagar", "MG Road", "Daresi No.2", "Raja Mandi",
    "Kheria Mod", "Surya Nagar", "Bhagwan Talkies", "Balkeshwar", "Ram Bagh"
]

# %%
timeline_ranges = {
    "Last to Last Decade": (datetime(2000, 1, 1), datetime(2010, 12, 31)),
    "Last Decade": (datetime(2011, 1, 1), datetime(2023, 12, 31)),
    "Ongoing": (datetime(2023, 1, 1), datetime(2025, 12, 31))
}

def get_project_duration_days(project_type):
    if any(keyword in project_type.lower() for keyword in ["road", "housing", "infra", "pipeline", "construction"]):
        return random.randint(365, 900)  # 1 to 2.5 years
    elif any(keyword in project_type.lower() for keyword in ["digital", "portal", "dashboard", "licensing"]):
        return random.randint(120, 360)  # 4 months to 1 year
    else:
        return random.randint(180, 720)  # default 6 months to 2 years
    
def get_project_status(start_date, end_date):
    today = datetime.today().date()
    if end_date < today:
        return "Completed"
    elif start_date <= today <= end_date:
        return "Ongoing"
    else:
        return "Upcoming"
    
def get_random_location():
    return random.choice(agra_locations)

def get_project_inventory(project_type):
    inventory_map = {
        "Road Construction": ["Excavators", "Asphalt Mixers", "Labor Crew", "Survey Kits"],
        "Smart Classrooms": ["Projectors", "Tablets", "Wi-Fi Equipment", "Digital Content Licenses"],
        "PHC Expansion": ["Hospital Beds", "Medical Instruments", "Water Supply Tanks", "Solar Lighting"],
        "Water Pipeline": ["PVC Pipes", "Excavation Units", "Leak Testing Kits", "Water Pumps"],
        "Affordable Housing": ["Concrete Mixers", "Bricks", "Steel Rods", "Architect Services"],
        "Waste Management System": ["Garbage Trucks", "Smart Bins", "GPS Devices", "RFID Tags"],
        "eShram Registry": ["Kiosks", "Biometric Scanners", "Data Entry Terminals"],
        "Village MIS": ["Desktops", "Connectivity Units", "Dashboards"],
        "Solar Rooftops": ["Solar Panels", "Inverters", "Mounting Structures", "Cable Harnesses"],
        "Skill Center": ["Laptops", "Tool Kits", "Projectors", "Lab Equipment"]
    }
    resources = inventory_map.get(project_type, ["Generic Tools", "Basic Workforce"])
    return ", ".join(random.sample(resources, k=random.randint(2, len(resources))))

# %%
data = []

for i in range(10000):
    dept, (proj_type, timeline_tag) = random.choice(list(project_definitions.items()))
    start_range, end_range = timeline_ranges[timeline_tag]

    start_date = start_range + timedelta(days=random.randint(0, (end_range - start_range).days - 180))
    duration = get_project_duration_days(proj_type)
    end_date = start_date + timedelta(days=duration)

    status = get_project_status(start_date.date(), end_date.date())

    location = get_random_location()

    collaborators = collaboration_map.get((dept, proj_type), [])
    other_departments = ", ".join(collaborators) if collaborators else "None"

    inventory = get_project_inventory(proj_type)

    data.append({
        "Project ID": f"PRJ{i+1:05}",
        "Department": dept,
        "Project Type": proj_type,
        "Timeline Tag": timeline_tag,
        "Start Date": start_date.date(),
        "End Date": end_date.date(),
        "Status": status,
        "Location": location,
        "Other Departments Involved": other_departments,
        "Inventory of Available Resources": inventory
    })

# %%
df = pd.DataFrame(data)
df.to_excel("Dataset.xlsx", index=False)
print("Generated mimic dataset.")
# Out:
# Generated mimic dataset.
